# %% [markdown]
# <a href="https://colab.research.google.com/github/vtejaswini66/EDA_Task2/blob/main/EDA_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_dataset.csv")

df.head()
# Out:
#    order_id        date  customer_id product_category   sales  quantity  \
# 0         1  2024-01-01         1051      Electronics  401.51         4
# 1         2  2024-01-02         1092         Clothing  261.27         1
# 2         3  2024-01-03         1014      Electronics  296.91         2
# 3         4  2024-01-04         1071      Electronics  256.41         2
# 4         5  2024-01-05         1060             Home  113.72         4
#
#    marketing_spend  revenue
# 0            82.23  1606.04
# 1            99.97   261.27
# 2            99.68   593.82
# 3            57.77   512.82
# 4            78.05   454.88

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          200 non-null    int64
#  1   date              200 non-null    object
#  2   customer_id       200 non-null    int64
#  3   product_category  200 non-null    object
#  4   sales             200 non-null    float64
#  5   quantity          200 non-null    int64
#  6   marketing_spend   200 non-null    float64
#  7   revenue           200 non-null    float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 12.6+ KB

# %%
df.describe()
# Out:
#          order_id  customer_id       sales    quantity  marketing_spend  \
# count  200.000000   200.000000  200.000000  200.000000        200.00000
# mean   100.500000  1049.010000  265.425600    2.380000         49.23840
# std     57.879185    29.667502  141.343507    1.167224         26.98987
# min      1.000000  1000.000000   25.200000    1.000000          6.38000
# 25%     50.750000  1024.500000  155.357500    1.000000         24.48750
# 50%    100.500000  1050.500000  272.865000    2.000000         48.21000
# 75%    150.250000  1074.250000  385.227500    3.000000         69.95250
# max    200.000000  1099.000000  495.440000    4.000000         99.97000
#
#            revenue
# count   200.000000
# mean    629.904300
# std     476.341489
# min      31.170000
# 25%     217.620000
# 50%     482.145000
# 75%     924.060000
# max    1911.560000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_dataset.csv")

# %%
df.head()
# Out:
#    order_id        date  customer_id product_category   sales  quantity  \
# 0         1  2024-01-01         1051      Electronics  401.51         4
# 1         2  2024-01-02         1092         Clothing  261.27         1
# 2         3  2024-01-03         1014      Electronics  296.91         2
# 3         4  2024-01-04         1071      Electronics  256.41         2
# 4         5  2024-01-05         1060             Home  113.72         4
#
#    marketing_spend  revenue
# 0            82.23  1606.04
# 1            99.97   261.27
# 2            99.68   593.82
# 3            57.77   512.82
# 4            78.05   454.88

# %%
df['sales'].hist()
plt.title("Sales Distribution")
plt.show()

# %%
df.columns
# Out:
# Index(['order_id', 'date', 'customer_id', 'product_category', 'sales',
#        'quantity', 'marketing_spend', 'revenue'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("cleaned_dataset.csv")

df.head()

df['product_category'].value_counts().plot(kind='bar')
plt.title("Product Category Count")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("cleaned_dataset.csv")

df.head()

df['product_category'].value_counts().plot(kind='bar')
plt.title("Product Category Count")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("cleaned_dataset.csv")

# Check columns
print(df.columns)

# Plot category count
df['product_category'].value_counts().plot(kind='bar')
plt.title("Product Category Count")
plt.show()
# Out:
# Index(['order_id', 'date', 'customer_id', 'product_category', 'sales',
#        'quantity', 'marketing_spend', 'revenue'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
numeric_df = df[['sales','quantity','marketing_spend','revenue']]

sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.barplot(x='product_category', y='sales', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('date')['revenue'].sum().plot()
plt.title("Revenue Over Time")
plt.show()

# %%
sns.scatterplot(x='marketing_spend', y='revenue', data=df)
plt.show()

# %%
sns.histplot(df['quantity'], bins=10)
plt.show()
